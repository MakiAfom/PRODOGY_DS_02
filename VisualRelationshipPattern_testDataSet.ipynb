# %% [markdown]
# <a href="https://colab.research.google.com/github/MakiAfom/PRODOGY_DS_02/blob/main/VisualRelationshipPattern_testDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset

test_dataset = pd.read_csv("train_1.csv", nrows=5)  # Load only the first 5 rows
print(test_dataset)


# Display basic statistics of the dataset
print(test_dataset.describe())

# Handle missing values
test_dataset.dropna(subset=['Embarked', 'Name', 'Cabin', 'Sex', 'Ticket', 'Fare'], inplace=True)
test_dataset['Age'].fillna(test_dataset['Age'].mean(), inplace=True)
test_dataset[['SibSp', 'Parch']] = test_dataset[['SibSp', 'Parch']].fillna(0)

# Visualize relationships between variables


sns.pairplot(test_dataset, hue='Survived', diag_kind='kde')
plt.show()

# Explore correlations between features
correlation_matrix = test_dataset.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# Explore survival rates based on categorical features
sns.countplot(x='Pclass', hue='Survived', data=test_dataset)
plt.title('Survival Count by Passenger Class')
plt.show()


#print(test_dataset)
#print(test_dataset.isnull().sum())
#print(train_dataset.info())

#print(test_dataset.info())
#print(test_dataset.head())
#print(test_dataset.tail())
#print(test_dataset.describe())
#print(test_dataset.shape)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...
